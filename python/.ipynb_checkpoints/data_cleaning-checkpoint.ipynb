# %%
import os

# show exactly where jupyter is running from
print("current directory:", os.getcwd())

# show everything in current folder
print("\nfiles here:", os.listdir("."))
# Out:
# current directory: C:\Users\deepj\Documents\customer-profitability-analysis\python
#
# files here: ['.gitkeep', '.ipynb_checkpoints', 'Untitled.ipynb']
